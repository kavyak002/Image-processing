# %%
#Negative of an image
import cv2
import numpy as np
img=cv2.imread('jambo.jpg')
print(img.dtype)
img_neg=255-img
cv2.imshow('negative of an image',img_neg)
cv2.waitKey(0)
# Out:
# uint8
# -1

# %%
#Log transformation
import cv2
import numpy as np
import matplotlib.pyplot as plt
   
# Read an image
image = cv2.imread('jambo.jpg')
   
# Apply log transformation method
c = 255 / np.log(1 + np.max(image))
log_image = c * (np.log(image + 1))
   
# Specify the data type so that
# float value will be converted to int
log_image = np.array(log_image, dtype = np.uint8)
   
# Display both images
plt.imshow(image)
plt.show()
plt.imshow(log_image)
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_7412/1679866293.py:10: RuntimeWarning: divide by zero encountered in log
#   log_image = c * (np.log(image + 1))

# %%
#block extraction from an image
from skimage.io import imshow,imread
import matplotlib.pyplot as plt
img1=imread('jambo.jpg')
imshow(img1)
fig,ax=plt.subplots(1,3,figsize=(6,4),sharey=True)
ax[0].imshow(img1[:,0:50])
ax[0].set_title('first block')
ax[1].imshow(img1[:,100:150])
ax[1].set_title('second block')
ax[2].imshow(img1[:,200:250])
ax[2].set_title('third block')
# Out:
# Text(0.5, 1.0, 'third block')

# %%
#mathematical operations on the image
#adding,subtracting,multiplipling,dividing
import cv2
img1=cv2.imread("star-1-300x168.jpg")
img2=cv2.imread("dot-300x168.jpg")
add=img1+img2
sub=img1-img2
mul=img1*img2
div=img1/img2
plt.imshow(add)
plt.show()
plt.imshow(sub)
plt.show()
plt.imshow(mul)
plt.show()
plt.imshow(div)
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_7412/1838173786.py:9: RuntimeWarning: divide by zero encountered in true_divide
#   div=img1/img2
# C:\Users\User\AppData\Local\Temp/ipykernel_7412/1838173786.py:9: RuntimeWarning: invalid value encountered in true_divide
#   div=img1/img2
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

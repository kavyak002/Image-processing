# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
image=cv2.imread('Tshirt.jpg')
plt.imshow(image)
image1=cv2.putText(img=image, text='Hello!', org=(80, 100), fontFace=cv2.FONT_HERSHEY_SCRIPT_COMPLEX, fontScale=1, color=(100, 10, 10),thickness=2)
plt.imshow(image1)
